# %% [markdown]
# # Preliminary Flowchart Analysis of Classes

# %% [markdown]
# ### Initial Visualization of How Varieties are filtered out

# %%
using PyPlot, Compat, DataFrames

# %%
# Initially, there were "." values in [:CLASS_OF],[:GRAD], and [BAGSSOLD].
# Converted them to -1 integers via Excel

# %%
"""
Checks a column for all unique types, using a for loop and a Dictionary
"""
function uniqueElements(df,acc)
    dimensions = size(df);
    print(dimensions)
    nRows = dimensions[1];
    # @assert nCols == 1 #Ensure only 1 row
    for element in df
        acc[element] = get(acc,element,0)+1
    end
end
# Out:
# uniqueElements

# %%
dataDirectory = "Student_Team_Competition_Syngenta_Data/";
file = "EXPERIMENT DATA CSV (Cleaned).csv";
readData = dataDirectory * file;
df = readtable(readData)
# Out:
# 258253×12 DataFrames.DataFrame
# │ Row    │ YEAR │ EXPERIMENT   │ LOCATION │ VARIETY   │ FAMILY     │ CHECK │
# ├────────┼──────┼──────────────┼──────────┼───────────┼────────────┼───────┤
# │ 1      │ 2009 │ "09YT000052" │ "3210"   │ "V000016" │ "FAM05619" │ true  │
# │ 2      │ 2009 │ "09YT000052" │ "3210"   │ "V000016" │ "FAM05619" │ true  │
# │ 3      │ 2009 │ "09YT000052" │ "3210"   │ "V000018" │ "FAM05619" │ true  │
# │ 4      │ 2009 │ "09YT000052" │ "3210"   │ "V000018" │ "FAM05619" │ true  │
# │ 5      │ 2009 │ "09YT000052" │ "3210"   │ "V000039" │ "FAM05625" │ true  │
# │ 6      │ 2009 │ "09YT000052" │ "3210"   │ "V000039" │ "FAM05625" │ true  │
# │ 7      │ 2009 │ "09YT000052" │ "3210"   │ "V000082" │ "FAM13251" │ true  │
# │ 8      │ 2009 │ "09YT000052" │ "3210"   │ "V000082" │ "FAM13251" │ true  │
# │ 9      │ 2009 │ "09YT000052" │ "3210"   │ "V030090" │ "FAM13986" │ false │
# │ 10     │ 2009 │ "09YT000052" │ "3210"   │ "V030090" │ "FAM13986" │ false │
# │ 11     │ 2009 │ "09YT000052" │ "3210"   │ "V030093" │ "FAM13986" │ false │
# ⋮
# │ 258242 │ 2014 │ "14YT005707" │ "3490"   │ "V152769" │ "FAM07213" │ false │
# │ 258243 │ 2014 │ "14YT005707" │ "3490"   │ "V152769" │ "FAM07213" │ false │
# │ 258244 │ 2014 │ "14YT005707" │ "3490"   │ "V155227" │ "FAM00603" │ true  │
# │ 258245 │ 2014 │ "14YT005707" │ "3490"   │ "V155227" │ "FAM00603" │ true  │
# │ 258246 │ 2014 │ "14YT005707" │ "3490"   │ "V155843" │ "FAM13991" │ true  │
# │ 258247 │ 2014 │ "14YT005707" │ "3490"   │ "V155843" │ "FAM13991" │ true  │
# │ 258248 │ 2014 │ "14YT005707" │ "3490"   │ "V155853" │ "FAM13521" │ true  │
# │ 258249 │ 2014 │ "14YT005707" │ "3490"   │ "V155853" │ "FAM13521" │ true  │
# │ 258250 │ 2014 │ "14YT005707" │ "3490"   │ "V156314" │ "FAM12531" │ true  │
# │ 258251 │ 2014 │ "14YT005707" │ "3490"   │ "V156314" │ "FAM12531" │ true  │
# │ 258252 │ 2014 │ "14YT005707" │ "3490"   │ "V156553" │ "FAM14238" │ true  │
# │ 258253 │ 2014 │ "14YT005707" │ "3490"   │ "V156553" │ "FAM14238" │ true  │
#
# │ Row    │ RM  │ REPNO │ YIELD   │ CLASS_OF │ GRAD │ BAGSOLD │
# ├────────┼─────┼───────┼─────────┼──────────┼──────┼─────────┤
# │ 1      │ 3.9 │ 1     │ 50.3023 │ -1       │ -1   │ -1      │
# │ 2      │ 3.9 │ 2     │ 48.3313 │ -1       │ -1   │ -1      │
# │ 3      │ 3.7 │ 1     │ 53.1032 │ -1       │ -1   │ -1      │
# │ 4      │ 3.7 │ 2     │ 53.1032 │ -1       │ -1   │ -1      │
# │ 5      │ 3.4 │ 1     │ 58.0811 │ -1       │ -1   │ -1      │
# │ 6      │ 3.4 │ 2     │ 58.2893 │ -1       │ -1   │ -1      │
# │ 7      │ 3.1 │ 1     │ 60.0522 │ -1       │ -1   │ -1      │
# │ 8      │ 3.1 │ 2     │ 59.4303 │ -1       │ -1   │ -1      │
# │ 9      │ 3.2 │ 1     │ 54.4524 │ -1       │ -1   │ -1      │
# │ 10     │ 3.2 │ 2     │ 53.9333 │ -1       │ -1   │ -1      │
# │ 11     │ 3.5 │ 1     │ 52.4814 │ -1       │ -1   │ -1      │
# ⋮
# │ 258242 │ 2.8 │ 1     │ 59.9085 │ -1       │ -1   │ -1      │
# │ 258243 │ 2.8 │ 2     │ 53.4084 │ -1       │ -1   │ -1      │
# │ 258244 │ 2.7 │ 1     │ 63.0916 │ -1       │ -1   │ -1      │
# │ 258245 │ 2.7 │ 2     │ 52.3362 │ -1       │ -1   │ -1      │
# │ 258246 │ 3.0 │ 1     │ 73.7622 │ 2011     │ 1    │ 871341  │
# │ 258247 │ 3.0 │ 2     │ 58.5208 │ 2011     │ 1    │ 871341  │
# │ 258248 │ 2.7 │ 1     │ 57.3599 │ 2011     │ 1    │ 761392  │
# │ 258249 │ 2.7 │ 2     │ 57.2151 │ 2011     │ 1    │ 761392  │
# │ 258250 │ 2.8 │ 1     │ 69.472  │ 2012     │ 1    │ 755156  │
# │ 258251 │ 2.8 │ 2     │ 64.0897 │ 2012     │ 1    │ 755156  │
# │ 258252 │ 2.9 │ 1     │ 72.7678 │ 2013     │ 1    │ 595119  │
# │ 258253 │ 2.9 │ 2     │ 60.1867 │ 2013     │ 1    │ 595119  │

# %%
MAPWORD = Dict([
    ("YEAR",1),
    ("EXPERIMENT",2),
    ("LOCATION",3),
    ("VARIETY",4),
    ("FAMILY",5),
    ("CHECK",6),
    ("RM",7),
    ("REPNO",8),
    ("YIELD",9),
    ("CLASS_OF",10),
    ("GRAD",11),
    ("BAGSOLD",12)
])
# Out:
# Dict{String,Int64} with 12 entries:
#   "EXPERIMENT" => 2
#   "CHECK"      => 6
#   "LOCATION"   => 3
#   "REPNO"      => 8
#   "VARIETY"    => 4
#   "YIELD"      => 9
#   "GRAD"       => 11
#   "RM"         => 7
#   "BAGSOLD"    => 12
#   "YEAR"       => 1
#   "CLASS_OF"   => 10
#   "FAMILY"     => 5

# %%
"""
Function to check number of unique entries for
whole dataframe
"""
function uniqueDataframe(df)
    (m,n) = size(df)
    acc = [];
    for i in 1:n
        dictacc = Dict{typeof(df[i][1]),Int64}()
        push!(acc,dictacc)
        uniqueElements(df[i],acc[i])
    end
    return acc
end
# Out:
# uniqueDataframe

# %%
description = uniqueDataframe(df)
description[4]; # VARIETY
description[5]; # FAMILY
description[10]; # CLASS_OF
# Out:
# (258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)(258253,)
# Dict{Int64,Int64} with 5 entries:
#   2011 => 10196
#   -1   => 231769
#   2013 => 5975
#   2014 => 4590
#   2012 => 5723

# %%
description[5]
# Out:
# Dict{String,Int64} with 1938 entries:
#   "FAM14483" => 77
#   "FAM10396" => 5
#   "FAM02899" => 3
#   "FAM13736" => 162
#   "FAM12772" => 11
#   "FAM14286" => 24
#   "FAM14547" => 266
#   "FAM14515" => 7
#   "FAM14469" => 387
#   "FAM14144" => 141
#   "FAM14161" => 162
#   "FAM13824" => 229
#   "FAM12507" => 511
#   "FAM07922" => 158
#   "FAM06065" => 36
#   "FAM00507" => 1468
#   "FAM13843" => 242
#   "FAM06586" => 60
#   "FAM08160" => 11
#   "FAM15670" => 2
#   "FAM05838" => 37
#   "FAM06602" => 267
#   "FAM05171" => 12
#   "FAM14476" => 12
#   "FAM13533" => 28
#   ⋮          => ⋮

# %%
uniqueClassesDF = Dict{Int64,Int64}()
uniqueElements(df[:CLASS_OF],uniqueClassesDF)
uniqueClassesDF
# Out:
# (258253,)
# Dict{Int64,Int64} with 5 entries:
#   2011 => 10196
#   -1   => 231769
#   2013 => 5975
#   2014 => 4590
#   2012 => 5723

# %% [markdown]
# ### Filter into Classes of 2011, 2012, 2013, 2014

# %%
df11 = df[ df[:CLASS_OF].==2011, :];
df12 = df[ df[:CLASS_OF].==2012, :];
df13 = df[ df[:CLASS_OF].==2013, :];
df14 = df[ df[:CLASS_OF].==2014, :];
classdf_list = [df11,df12,df13,df14]
# Out:
# 4-element Array{DataFrames.DataFrame,1}:
#  10196×12 DataFrames.DataFrame
# │ Row   │ YEAR │ EXPERIMENT   │ LOCATION │ VARIETY   │ FAMILY     │ CHECK │
# ├───────┼──────┼──────────────┼──────────┼───────────┼────────────┼───────┤
# │ 1     │ 2009 │ "09YT000220" │ "3310"   │ "V136860" │ "FAM13983" │ false │
# │ 2     │ 2009 │ "09YT000220" │ "3310"   │ "V136860" │ "FAM13983" │ false │
# │ 3     │ 2009 │ "09YT000321" │ "3310"   │ "V120205" │ "FAM12494" │ false │
# │ 4     │ 2009 │ "09YT000321" │ "3310"   │ "V120205" │ "FAM12494" │ false │
# │ 5     │ 2009 │ "09YT000395" │ "1110"   │ "V148493" │ "FAM07635" │ false │
# │ 6     │ 2009 │ "09YT000395" │ "1110"   │ "V148493" │ "FAM07635" │ false │
   │ "V156314" │ "FAM12531" │ true  │ 2.8 │
# │ 5723 │ 2014 │ "14YT005707" │ "3490"   │ "V156314" │ "FAM12531" │ true  │ 2.8 │
#
# │ Row  │ REPNO │ YIELD   │ CLASS_OF │ GRAD │ BAGSOLD │
# ├──────┼───────┼─────────┼──────────┼──────┼─────────┤
# │ 1    │ 1     │ 44.9725 │ 2012     │ 0    │ 0       │
# │ 2    │ 2     │ 50.4189 │ 2012     │ 0    │ 0       │
# │ 3    │ 1     │ 47.023  │ 2012     │ 0    │ 0       │
# │ 4    │ 2     │ 48.141  │ 2012     │ 0    │ 0       │
# │ 5    │ 1     │ 61.655  │ 2012     │ 0    │ 0       │
# │ 6    │ 2     │ 58.0819 │ 2012     │ 0    │ 0       │
# │ 7    │ 1     │ 70.7351 │ 2012     │ 0    │ 0       │
# │ 8    │ 2     │ 71.8761 │ 2012     │ 0    │ 0       │
# │ 9    │ 1     │ 72.809  │ 2012     │ 0    │ 0       │
# │ 10   │ 2     │ 71.3569 │ 2012     │ 0    │ 0       │
# │ 11   │ 1     │ 64.1124 │ 2012     │ 0    │ 0       │
# ⋮
# │ 5712 │ 1     │ 62.4714 │ 2012     │ 1    │ 755156  │
# │ 5713 │ 2     │ 60.8434 │ 2012     │ 1    │ 755156  │
# │ 5714 │ 1     │ 63.514  │ 2012     │ 1    │ 755156  │
# │ 5715 │ 2     │ 61.4447 │ 2012     │ 1    │ 755156  │
# │ 5716 │ 1     │ 47.1514 │ 2012     │ 1    │ 755156  │
# │ 5717 │ 2     │ 51.0385 │ 2012     │ 1    │ 755156  │
# │ 5718 │ 1     │ 51.6079 │ 2012     │ 1    │ 755156  │
# │ 5719 │ 2     │ 57.928  │ 2012     │ 1    │ 755156  │
# │ 5720 │ 1     │ 61.5241 │ 2012     │ 1    │ 755156  │
# │ 5721 │ 2     │ 64.5246 │ 2012     │ 1    │ 755156  │
# │ 5722 │ 1     │ 69.472  │ 2012     │ 1    │ 755156  │
# │ 5723 │ 2     │ 64.0897 │ 2012     │ 1    │ 755156  │
#  5975×12 DataFrames.DataFrame
# │ Row  │ YEAR │ EXPERIMENT   │ LOCATION │ VARIETY   │ FAMILY     │ CHECK │ RM  │
# ├──────┼──────┼──────────────┼──────────┼───────────┼────────────┼───────┼─────┤
# │ 1    │ 2009 │ "09YT000406" │ "2260"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 2    │ 2009 │ "09YT000406" │ "2260"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 3    │ 2009 │ "09YT000406" │ "2270"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 4    │ 2009 │ "09YT000406" │ "2270"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 5    │ 2009 │ "09YT000406" │ "2290"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 6    │ 2009 │ "09YT000406" │ "2290"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 7    │ 2009 │ "09YT000406" │ "3120"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 8    │ 2009 │ "09YT000406" │ "3120"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 9    │ 2009 │ "09YT000406" │ "3210"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 10   │ 2009 │ "09YT000406" │ "3210"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# │ 11   │ 2010 │ "10YT001743" │ "2170"   │ "V139548" │ "FAM13984" │ false │ 3.0 │
# ⋮
# │ 5964 │ 2014 │ "14YT005707" │ "3430"   │ "V152053" │ "FAM14333" │ true  │ 3.0 │
# │ 5965 │ 2014 │ "14YT005707" │ "3430"   │ "V152053" │ "FAM14333" │ true  │ 3.0 │
# │ 5966 │ 2014 │ "14YT005707" │ "3430"   │ "V152079" │ "FAM11179" │ true  │ 2.7 │
# │ 5967 │ 2014 │ "14YT005707" │ "3430"   │ "V152079" │ "FAM11179" │ true  │ 2.7 │
# │ 5968 │ 2014 │ "14YT005707" │ "3430"   │ "V156553" │ "FAM14238" │ true  │ 2.9 │
# │ 5969 │ 2014 │ "14YT005707" │ "3430"   │ "V156553" │ "FAM14238" │ true  │ 2.9 │
# │ 5970 │ 2014 │ "14YT005707" │ "3490"   │ "V152053" │ "FAM14333" │ true  │ 3.0 │
# │ 5971 │ 2014 │ "14YT005707" │ "3490"   │ "V152053" │ "FAM14333" │ true  │ 3.0 │
# │ 5972 │ 2014 │ "14YT005707" │ "3490"   │ "V152079" │ "FAM11179" │ true  │ 2.7 │
# │ 5973 │ 2014 │ "14YT005707" │ "3490"   │ "V152079" │ "FAM11179" │ true  │ 2.7 │
# │ 5974 │ 2014 │ "14YT005707" │ "3490"   │ "V156553" │ "FAM14238" │ true  │ 2.9 │
# │ 5975 │ 2014 │ "14YT005707" │ "3490"   │ "V156553" │ "FAM14238" │ true  │ 2.9 │
#
# │ Row  │ REPNO │ YIELD   │ CLASS_OF │ GRAD │ BAGSOLD │
# ├──────┼───────┼─────────┼──────────┼──────┼─────────┤
# │ 1    │ 1     │ 70.0322 │ 2013     │ 0    │ 0       │
# │ 2    │ 2     │ 66.9049 │ 2013     │ 0    │ 0       │
# │ 3    │ 1     │ 53.0832 │ 2013     │ 0    │ 0       │
# │ 4    │ 2     │ 63.4674 │ 2013     │ 0    │ 0       │
# │ 5    │ 1     │ 59.9805 │ 2013     │ 0    │ 0       │
# │ 6    │ 2     │ 59.6456 │ 2013     │ 0    │ 0       │
# │ 7    │ 1     │ 62.5488 │ 2013     │ 0    │ 0       │
# │ 8    │ 2     │ 49.1457 │ 2013     │ 0    │ 0       │
# │ 9    │ 1     │ 73.328  │ 2013     │ 0    │ 0       │
# │ 10   │ 2     │ 82.9728 │ 2013     │ 0    │ 0       │
# │ 11   │ 1     │ 71.4851 │ 2013     │ 0    │ 0       │
# ⋮
# │ 5964 │ 1     │ 61.3338 │ 2013     │ 1    │ 940184  │
# │ 5965 │ 2     │ 61.7809 │ 2013     │ 1    │ 940184  │
# │ 5966 │ 1     │ 61.6131 │ 2013     │ 1    │ 1357745 │
# │ 5967 │ 2     │ 65.4161 │ 2013     │ 1    │ 1357745 │
# │ 5968 │ 1     │ 57.1469 │ 2013     │ 1    │ 595119  │
# │ 5969 │ 2     │ 64.6303 │ 2013     │ 1    │ 595119  │
# │ 5970 │ 1     │ 62.5545 │ 2013     │ 1    │ 940184  │
# │ 5971 │ 2     │ 59.4944 │ 2013     │ 1    │ 940184  │
# │ 5972 │ 1     │ 50.661  │ 2013     │ 1    │ 1357745 │
# │ 5973 │ 2     │ 64.5563 │ 2013     │ 1    │ 1357745 │
# │ 5974 │ 1     │ 72.7678 │ 2013     │ 1    │ 595119  │
# │ 5975 │ 2     │ 60.1867 │ 2013     │ 1    │ 595119  │
#  4590×12 DataFrames.DataFrame
# │ Row  │ YEAR │ EXPERIMENT   │ LOCATION │ VARIETY   │ FAMILY     │ CHECK │ RM  │
# ├──────┼──────┼──────────────┼──────────┼───────────┼────────────┼───────┼─────┤
# │ 1    │ 2012 │ "12YT002964" │ "2340"   │ "V114589" │ "FAM11189" │ false │ 3.1 │
# │
# │ 4579 │ 1     │ 41.2713 │ 2014     │ -1   │ -1      │
# │ 4580 │ 2     │ 59.2429 │ 2014     │ -1   │ -1      │
# │ 4581 │ 1     │ 59.7603 │ 2014     │ -1   │ -1      │
# │ 4582 │ 2     │ 57.7394 │ 2014     │ -1   │ -1      │
# │ 4583 │ 1     │ 71.1877 │ 2014     │ -1   │ -1      │
# │ 4584 │ 2     │ 61.6861 │ 2014     │ -1   │ -1      │
# │ 4585 │ 1     │ 59.1026 │ 2014     │ -1   │ -1      │
# │ 4586 │ 2     │ 58.7214 │ 2014     │ -1   │ -1      │
# │ 4587 │ 1     │ 60.6044 │ 2014     │ -1   │ -1      │
# │ 4588 │ 2     │ 63.6388 │ 2014     │ -1   │ -1      │
# │ 4589 │ 1     │ 68.9769 │ 2014     │ -1   │ -1      │
# │ 4590 │ 2     │ 64.0897 │ 2014     │ -1   │ -1      │

# %%
description11 = uniqueDataframe(df11);
description12 = uniqueDataframe(df12);
description13 = uniqueDataframe(df13);
description14 = uniqueDataframe(df14);
# Out:
# (10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(10196,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5723,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(5975,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)(4590,)

# %% [markdown]
# ### Filter each class of by the previous years (3 years ago)

# %%
yearlist = 2009:2014
df11_by_year = []; description11_by_year = [];
df12_by_year = []; description12_by_year = [];
df13_by_year = []; description13_by_year = [];
df14_by_year = []; description14_by_year = [];

df_by_year_list = [df11_by_year,df12_by_year,df13_by_year,df14_by_year];
describe_by_year = [description11_by_year,description12_by_year,
    description13_by_year,description14_by_year];

for i in 1:length(classdf_list)
    dfdummy = (classdf_list[i]);
    println("OK")
    for year in yearlist
        println((i,year))
        cutdfdummy = dfdummy[dfdummy[:YEAR].==year,:];
        push!(df_by_year_list[i],cutdfdummy);
        push!(describe_by_year[i],uniqueDataframe(cutdfdummy) );
    end
end
# Out:
# OK
# (1,2009)
# (103,)(103,)(103,)(103,)(103,)(103,)(103,)(103,)(103,)(103,)(103,)(103,)(1,2010)
# (449,)(449,)(449,)(449,)(449,)(449,)(449,)(449,)(449,)(449,)(449,)(449,)(1,2011)
# (4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(4494,)(1,2012)
# (3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(3597,)(1,2013)
# (1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1000,)(1,2014)
# (553,)(553,)(553,)(553,)(553,)(553,)(553,)(553,)(553,)(553,)(553,)(553,)OK
# (2,2009)
# (10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(2,2010)
# (94,)(94,)(94,)(94,)(94,)(94,)(94,)(94,)(94,)(94,)(94,)(94,)(2,2011)
# (1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(1469,)(2,2012)
# (1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(1889,)(2,2013)
# (1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(1467,)(2,2014)
# (794,)(794,)(794,)(794,)(794,)(794,)(794,)(794,)(794,)(794,)(794,)(794,)OK
# (3,2009)
# (10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(10,)(3,2010)
# (32,)(32,)(32,)(32,)(32,)(32,)(32,)(32,)(32,)(32,)(32,)(32,)(3,2011)
# (458,)(458,)(458,)(458,)(458,)(458,)(458,)(458,)(458,)(458,)(458,)(458,)(3,2012)
# (1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(1618,)(3,2013)
# (2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(2288,)(3,2014)
# (1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)(1569,)OK
# (4,2009)
# LoadError: BoundsError: attempt to access 0-element BitArray{1} at index [1]
# while loading In[21], in expression starting on line 10
#
#  in throw_boundserror(::BitArray{1}, ::Tuple{Int64}) at ./abstractarray.jl:355
#  in checkbounds at ./abstractarray.jl:284 [inlined]
#  in getindex at ./bitarray.jl:537 [inlined]
#  in getindex(::DataArrays.DataArray{Int64,1}, ::Int64) at /home/zilong/.julia/v0.5/DataArrays/src/indexing.jl:119
#  in uniqueDataframe(::DataFrames.DataFrame) at ./In[6]:9
#  in macro expansion; at ./In[21]:17 [inlined]
#  in anonymous at ./<missing>:?

# %%
varIndex = get(MAPWORD,"VARIETY",9999)
description11_by_year[1][varIndex]
# Out:
# Dict{String,Int64} with 16 entries:
#   "V155801" => 4
#   "V155842" => 6
#   "V155918" => 6
#   "V155820" => 8
#   "V120205" => 2
#   "V155891" => 8
#   "V155786" => 3
#   "V155890" => 8
#   "V155853" => 4
#   "V136860" => 2
#   "V120075" => 17
#   "V148493" => 16
#   "V155843" => 6
#   "V155859" => 4
#   "V150509" => 5
#   "V155800" => 4

# %%
description11_by_year[2][varIndex]
# Out:
# Dict{String,Int64} with 15 entries:
#   "V155801" => 35
#   "V155842" => 33
#   "V155820" => 35
#   "V155891" => 15
#   "V155786" => 32
#   "V150601" => 18
#   "V155890" => 14
#   "V155853" => 33
#   "V120075" => 36
#   "V148493" => 28
#   "V155843" => 33
#   "V155859" => 34
#   "V150481" => 34
#   "V150509" => 32
#   "V155800" => 37

# %%
description11_by_year[3][varIndex]
# Out:
# Dict{String,Int64} with 31 entries:
#   "V155801" => 183
#   "V155842" => 313
#   "V155918" => 57
#   "V155820" => 416
#   "V120205" => 57
#   "V150536" => 58
#   "V155891" => 244
#   "V120038" => 15
#   "V150296" => 60
#   "V150844" => 70
#   "V150601" => 84
#   "V155890" => 199
#   "V155786" => 61
#   "V155853" => 61
#   "V103484" => 36
#   "V150487" => 10
#   "V136860" => 170
#   "V136828" => 58
#   "V151663" => 53
#   "V120075" => 327
#   "V120247" => 58
#   "V155843" => 1115
#   "V137240" => 53
#   "V148493" => 55
#   "V150510" => 60
#   ⋮         => ⋮

# %%
description11_by_year[4][varIndex]
# Out:
# Dict{String,Int64} with 15 entries:
#   "V155842" => 717
#   "V155918" => 591
#   "V155820" => 468
#   "V120410" => 64
#   "V120038" => 11
#   "V150844" => 217
#   "V155890" => 391
#   "V155853" => 53
#   "V103484" => 31
#   "V111862" => 20
#   "V137240" => 52
#   "V148493" => 58
#   "V155843" => 596
#   "V150509" => 170
#   "V136868" => 158

# %%
description11_by_year[5][varIndex]
# Out:
# Dict{String,Int64} with 7 entries:
#   "V155842" => 236
#   "V155918" => 117
#   "V155820" => 184
#   "V150844" => 98
#   "V155843" => 120
#   "V155890" => 60
#   "V155853" => 185

# %%
description11_by_year[6][varIndex]
# Out:
# Dict{String,Int64} with 5 entries:
#   "V155842" => 179
#   "V155918" => 64
#   "V155820" => 63
#   "V155843" => 127
#   "V155853" => 120

# %%
df_by_year_list[1][6]
